# %%
import pandas as pd

df = pd.read_csv("../../../data/rq3/results/survey_with_codes.csv", header=[0,1,2])
df = df.droplevel(2, axis=1)

# %%
df = df.droplevel(1, axis=1)
df = df[df["Finished"]]
len(df)
# Out:
# 278

# %%
# Years of experience software and years of experience on social coding platforms
df[["Q8", "Q41"]].hist(figsize=(15,5))
# Out:
# array([[<AxesSubplot:title={'center':'Q8'}>,
#         <AxesSubplot:title={'center':'Q41'}>]], dtype=object)

# %%
print(df["Dev/Maintain choice"].value_counts())
df["Dev/Maintain choice"].value_counts().plot.bar(rot=0)
# Out:
# Maintainer/Project Manager    143
# Code contributor              135
# Name: Dev/Maintain choice, dtype: int64
# <AxesSubplot:>

# %%
# How often people contribute to other projects, self-owned projects, review others contributions
a=df["Q12_1"].value_counts(sort=False)
b=df["Q12_2"].value_counts(sort=False)
c=df["Q12_3"].value_counts(sort=False)

pd.DataFrame([a,b,c]).transpose().plot.bar(rot=45)
# Out:
# <AxesSubplot:>

# %%
# Work in software development in professional capacity
df["Q15"].value_counts().plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
# How long: automatic testing, manual testing, code review
a=df["Q17_1"].value_counts(sort=False)
b=df["Q17_2"].value_counts(sort=False)
c=df["Q17_3"].value_counts(sort=False)

pd.DataFrame([a,b,c]).transpose().plot.bar(rot=45)
# Out:
# <AxesSubplot:>

# %%
# How important is automatic testing
df["Q18_1"].value_counts().plot.bar(rot=12)
# Out:
# <AxesSubplot:>

# %%
# How often do you use code coverage outside Github
df["Q20_1"].value_counts().plot.bar(rot=20)
# Out:
# <AxesSubplot:>

# %%
# How often do you use coverage: while contributing, while reviewing
a=df["Q43_1"].value_counts(sort=False)
b=df["Q43_2"].value_counts(sort=False)

pd.DataFrame([a,b]).transpose().plot.bar(rot=45)
# Out:
# <AxesSubplot:>

# %%
# 4 opinion statements: coverage good metric, coverage provides incentive,
# more likely to accept pr with high coverage, more likely to have pr accepted if good coverage
a=df["Q30_1"].value_counts(sort=False)
b=df["Q30_2"].value_counts(sort=False)
c=df["Q30_3"].value_counts(sort=False)
d=df["Q30_4"].value_counts(sort=False)

print(len(df["Q30_1"].dropna()))
print(len(df["Q30_2"].dropna()))
print(len(df["Q30_3"].dropna()))
print(len(df["Q30_4"].dropna()))

pd.DataFrame([a,b]).plot.barh(rot=45)
pd.DataFrame([c]).transpose().plot.bar(rot=45)
pd.DataFrame([d]).transpose().plot.bar(rot=45)
# Out:
# 268
# 268
# 138
# 128
# <AxesSubplot:>

# %%
# How often you write tests?
df["Q23_1"].value_counts().plot.bar(rot=20)
# Out:
# <AxesSubplot:>

# %%
# How often write tests just for improving coverage
df["Q24_1"].value_counts().plot.bar(rot=45)
# Out:
# <AxesSubplot:>

# %%
# How often: asked to improve coverage by human, by bot, have to ask to improve coverage
a=df["Q26_1"].value_counts(sort=False)
b=df["Q26_2"].value_counts(sort=False)
c=df["Q28_1"].value_counts(sort=False)

pd.DataFrame([a,b,c]).transpose().plot.bar(rot=45)
# Out:
# <AxesSubplot:>

# %%
# Ignore failing check: while contributing, while reviewing
a=df["Q36_1"].value_counts(sort=False)
b=df["Q36_2"].value_counts(sort=False)

pd.DataFrame([a,b]).transpose().plot.bar(rot=45)
# Out:
# <AxesSubplot:>

# %%
# Ranking question. Top answer --> highest incentive
# 114=comment
# 115=statuscheck
# 116=annotating uncovered lines
# 118=Email/slack notification
# 119=Reminding of guidelines
options = {
     "Q47_114": "comment",
     "Q47_115": "status check",
     "Q47_116": "annotating uncovered lines",
     "Q47_118": "email/slac notification",
     "Q47_119": "reminding of guidelines",
}
(df[[k for k in options]] == 1.0).sum(axis=0).rename(options).plot.barh(rot=0)
# df[["Q47_114",
# "Q47_115",
# "Q47_116",
# "Q47_118",
# "Q47_119"]].apply(lambda x: x.value_counts()).head(1).plot.bar(rot=1)
# Out:
# <AxesSubplot:>

# %%
df[["Q47_114",
     "Q47_115",
     "Q47_116",
     "Q47_118",
     "Q47_119"]].sum(axis=0).plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
df[["Q47_114",
    "Q47_115",
    "Q47_116",
    "Q47_118",
    "Q47_119"]].mean(axis=0).plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
df.groupby(["Dev/Maintain choice", "Q30_1"]).size().unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='Dev/Maintain choice'>

# %%
df.groupby(["Dev/Maintain choice", "Q30_2"]).size().unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='Dev/Maintain choice'>

# %%
df.groupby(["Dev/Maintain choice", "Q24_1"]).size().unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='Dev/Maintain choice'>

# %%
df.groupby(["Dev/Maintain choice", "Q23_1"]).size().unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='Dev/Maintain choice'>

# %%
# TODO
# for each question: count empty respones
# Count empty response for each participant
# Stacked bars for likert
# Make plots nicer --> bigger, add title, better descriptions.
# Think about stat. tests
